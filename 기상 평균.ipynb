# %%
import pandas as pd

# %%
df = pd.read_csv('2017_avg_climate.csv', encoding='cp949')

# %%
df
# Out:
#        지점  지점명          일시  평균기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%)  \
# 0      98  동두천  2017-01-01       1.8       NaN         0.6        76.3
# 1      98  동두천  2017-01-02       4.5       0.0         1.3        76.9
# 2      98  동두천  2017-01-03       0.7       NaN         1.2        66.5
# 3      98  동두천  2017-01-04       2.5       NaN         1.0        62.1
# 4      98  동두천  2017-01-05       2.7       NaN         1.3        60.1
# ...   ...  ...         ...       ...       ...         ...         ...
# 5835  281   영천  2017-12-27      -2.9       NaN         4.3        23.0
# 5836  281   영천  2017-12-28      -0.9       NaN         2.2        38.5
# 5837  281   영천  2017-12-29       3.9       NaN         2.6        58.4
# 5838  281   영천  2017-12-30       2.3       NaN         0.8        68.8
# 5839  281   영천  2017-12-31       3.3       0.0         3.8        41.0
#
#       평균 현지기압(hPa)
# 0           1013.8
# 1           1008.4
# 2           1010.1
# 3           1010.1
# ...

# %%
df['temp_5'] = ''
df['rain_5'] = ''
df['wind_5'] = ''
df['humidity_5'] = ''
df.drop('평균 현지기압(hPa)', axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5840 entries, 0 to 5839
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   지점          5840 non-null   int64
#  1   지점명         5840 non-null   object
#  2   일시          5840 non-null   object
#  3   평균기온(°C)    5839 non-null   float64
#  4   일강수량(mm)    2108 non-null   float64
#  5   평균 풍속(m/s)  5837 non-null   float64
#  6   평균 상대습도(%)  5840 non-null   float64
#  7   temp_5      5840 non-null   object
#  8   rain_5      5840 non-null   object
#  9   wind_5      5840 non-null   object
#  10  humidity_5  5840 non-null   object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 502.0+ KB

# %%
df.isna().sum()
# Out:
# 지점               0
# 지점명              0
# 일시               0
# 평균기온(°C)         1
# 일강수량(mm)      3732
# 평균 풍속(m/s)       3
# 평균 상대습도(%)       0
# temp_5           0
# rain_5           0
# wind_5           0
# humidity_5       0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df
# Out:
#        지점  지점명          일시  평균기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%) temp_5  \
# 0      98  동두천  2017-01-01       1.8       0.0         0.6        76.3
# 1      98  동두천  2017-01-02       4.5       0.0         1.3        76.9
# 2      98  동두천  2017-01-03       0.7       0.0         1.2        66.5
# 3      98  동두천  2017-01-04       2.5       0.0         1.0        62.1
# 4      98  동두천  2017-01-05       2.7       0.0         1.3        60.1
# ...   ...  ...         ...       ...       ...         ...         ...    ...
# 5835  281   영천  2017-12-27      -2.9       0.0         4.3        23.0
# 5836  281   영천  2017-12-28      -0.9       0.0         2.2        38.5
# 5837  281   영천  2017-12-29       3.9       0.0         2.6        58.4
# 5838  281   영천  2017-12-30       2.3       0.0         0.8        68.8
# 5839  281   영천  2017-12-31       3.3       0.0         3.8        41.0
#
#      rain_5 wind_5 humidity_5
# 0
# 1
# 2
# 3
# 4
# ...     ...    ...        ...
# 5835
# 5836
# 5837
# ...

# %% [raw]
# df_2016 = pd.read_csv('2016_avg_climate.csv', encoding='cp949')
# df_2016

# %% [raw]
# df_2016[91:]

# %% [raw]
# for j in range(5):
#     for i in range(92, 97):
#         df['rain_5'][j] = (df_2016['일강수량(mm)'][i-1]+df_2016['일강수량(mm)'][i-2]+df_2016['일강수량(mm)'][i-3]+df_2016['일강수량(mm)'][i-4]+df_2016['일강수량(mm)'][i-5])/5
#         df['wind_5'][j] = (df_2016['평균 풍속(m/s)'][i-1]+df_2016['평균 풍속(m/s)'][i-2]+df_2016['평균 풍속(m/s)'][i-3]+df_2016['평균 풍속(m/s)'][i-4]+df_2016['평균 풍속(m/s)'][i-5])/5

# %% [raw]
# for i in range(5,10):
#     print( df['일시'][i-1])

# %%
for i in range(5, 6205):
    df['temp_5'][i] = (df['평균기온(°C)'][i-1]+df['평균기온(°C)'][i-2]+df['평균기온(°C)'][i-3]+df['평균기온(°C)'][i-4]+df['평균기온(°C)'][i-5])/5
    df['rain_5'][i] = (df['일강수량(mm)'][i-1]+df['일강수량(mm)'][i-2]+df['일강수량(mm)'][i-3]+df['일강수량(mm)'][i-4]+df['일강수량(mm)'][i-5])/5
    df['wind_5'][i] = (df['평균 풍속(m/s)'][i-1]+df['평균 풍속(m/s)'][i-2]+df['평균 풍속(m/s)'][i-3]+df['평균 풍속(m/s)'][i-4]+df['평균 풍속(m/s)'][i-5])/5
    df['humidity_5'][i] = (df['평균 상대습도(%)'][i-1]+df['평균 상대습도(%)'][i-2]+df['평균 상대습도(%)'][i-3]+df['평균 상대습도(%)'][i-4]+df['평균 상대습도(%)'][i-5])/5
# Out:
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/3961339245.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['temp_5'][i] = (df['평균기온(°C)'][i-1]+df['평균기온(°C)'][i-2]+df['평균기온(°C)'][i-3]+df['평균기온(°C)'][i-4]+df['평균기온(°C)'][i-5])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/3961339245.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rain_5'][i] = (df['일강수량(mm)'][i-1]+df['일강수량(mm)'][i-2]+df['일강수량(mm)'][i-3]+df['일강수량(mm)'][i-4]+df['일강수량(mm)'][i-5])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/3961339245.py:4: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#        지점  지점명          일시  평균기온(°C)  일강수량(mm)  평균 풍속(m/s)  평균 상대습도(%) temp_5  \
# 0      98  동두천  2017-01-01       1.8       0.0         0.6        76.3
# 1      98  동두천  2017-01-02       4.5       0.0         1.3        76.9
# 2      98  동두천  2017-01-03       0.7       0.0         1.2        66.5
# 3      98  동두천  2017-01-04       2.5       0.0         1.0        62.1
# 4      98  동두천  2017-01-05       2.7       0.0         1.3        60.1
# ...   ...  ...         ...       ...       ...         ...         ...    ...
# 5835  281   영천  2017-12-27      -2.9       0.0         4.3        23.0   1.06
# 5836  281   영천  2017-12-28      -0.9       0.0         2.2        38.5   0.34
# 5837  281   영천  2017-12-29       3.9       0.0         2.6        58.4   0.14
# 5838  281   영천  2017-12-30       2.3       0.0         0.8        68.8   0.38
# 5839  281   영천  2017-12-31       3.3       0.0         3.8        41.0   0.62
#
#      rain_5 wind_5 humidity_5
# 0
# 1
# 2
# 3
# 4
# ...

# %%
df.loc[df['지점'] == 98, '지점'] = '경기도'
df.loc[df['지점'] == 106, '지점'] = '강원도'
df.loc[df['지점'] == 108, '지점'] = '서울특별시'
df.loc[df['지점'] == 112, '지점'] = '인천광역시'
df.loc[df['지점'] == 127, '지점'] = '충청북도'
df.loc[df['지점'] == 133, '지점'] = '대전광역시'
df.loc[df['지점'] == 143, '지점'] = '대구광역시'
df.loc[df['지점'] == 146, '지점'] = '전라북도'
df.loc[df['지점'] == 152, '지점'] = '울산광역시'
df.loc[df['지점'] == 155, '지점'] = '경상남도'
df.loc[df['지점'] == 156, '지점'] = '광주광역시'
df.loc[df['지점'] == 159, '지점'] = '부산광역시'
df.loc[df['지점'] == 168, '지점'] = '전라남도'
df.loc[df['지점'] == 184, '지점'] = '제주도'
df.loc[df['지점'] == 236, '지점'] = '충청남도'
df.loc[df['지점'] == 281, '지점'] = '경상북도'

# %%
df.rename(columns={'지점':'do', '지점명':'observatory', '일시':'day', '평균기온(°C)':'temp_avg', '일강수량(mm)':'rain_avg', '평균 풍속(m/s)':'wind_avg', '평균 상대습도(%)':'humidity_avg'}, inplace=True)

# %%
df
# Out:
#         do observatory         day  temp_avg  rain_avg  wind_avg  \
# 0      경기도         동두천  2017-01-01       1.8       0.0       0.6
# 1      경기도         동두천  2017-01-02       4.5       0.0       1.3
# 2      경기도         동두천  2017-01-03       0.7       0.0       1.2
# 3      경기도         동두천  2017-01-04       2.5       0.0       1.0
# 4      경기도         동두천  2017-01-05       2.7       0.0       1.3
# ...    ...         ...         ...       ...       ...       ...
# 5835  경상북도          영천  2017-12-27      -2.9       0.0       4.3
# 5836  경상북도          영천  2017-12-28      -0.9       0.0       2.2
# 5837  경상북도          영천  2017-12-29       3.9       0.0       2.6
# 5838  경상북도          영천  2017-12-30       2.3       0.0       0.8
# 5839  경상북도          영천  2017-12-31       3.3       0.0       3.8
#
#       humidity_avg temp_5 rain_5 wind_5 humidity_5
# 0             76.3
# 1             76.9
# 2             66.5
# 3             62.1
# 4             60.1
# ...

# %%
df_2016 = pd.read_csv('2017_climate_final.csv')

# %%
df_2016 = df_2016.fillna(0)

# %%
df.columns
# Out:
# Index(['do', 'observatory', 'day', 'temp_avg', 'rain_avg', 'wind_avg',
#        'humidity_avg', 'temp_5', 'rain_5', 'wind_5', 'humidity_5'],
#       dtype='object')

# %%
df['temp_5'][0]= (df_2016['평균기온(°C)'][91]+df_2016['평균기온(°C)'][92]+df_2016['평균기온(°C)'][93]+df_2016['평균기온(°C)'][94]+df_2016['평균기온(°C)'][95])/5
df['rain_5'][0] = (df_2016['일강수량(mm)'][91]+df_2016['일강수량(mm)'][92]+df_2016['일강수량(mm)'][93]+df_2016['일강수량(mm)'][94]+df_2016['일강수량(mm)'][95])/5
df['wind_5'][0] = (df_2016['평균 풍속(m/s)'][91]+df_2016['평균 풍속(m/s)'][92]+df_2016['평균 풍속(m/s)'][93]+df_2016['평균 풍속(m/s)'][94]+df_2016['평균 풍속(m/s)'][95])/5
df['humidity_5'][0] = (df_2016['평균 상대습도(%)'][91]+df_2016['평균 상대습도(%)'][92]+df_2016['평균 상대습도(%)'][93]+df_2016['평균 상대습도(%)'][94]+df_2016['평균 상대습도(%)'][95])/5
# Out:
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/3302174246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['temp_5'][0]= (df_2016['평균기온(°C)'][91]+df_2016['평균기온(°C)'][92]+df_2016['평균기온(°C)'][93]+df_2016['평균기온(°C)'][94]+df_2016['평균기온(°C)'][95])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/3302174246.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rain_5'][0] = (df_2016['일강수량(mm)'][91]+df_2016['일강수량(mm)'][92]+df_2016['일강수량(mm)'][93]+df_2016['일강수량(mm)'][94]+df_2016['일강수량(mm)'][95])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/3302174246.py:3: SettingWithCopyWarning:
# ...

# %%
df['temp_5'][1]= (df_2016['평균기온(°C)'][92]+df_2016['평균기온(°C)'][93]+df_2016['평균기온(°C)'][94]+df_2016['평균기온(°C)'][95]+df['temp_avg'][0])/5
df['rain_5'][1] = (df_2016['일강수량(mm)'][92]+df_2016['일강수량(mm)'][93]+df_2016['일강수량(mm)'][94]+df_2016['일강수량(mm)'][95]+df['rain_avg'][0])/5
df['wind_5'][1] = (df_2016['평균 풍속(m/s)'][92]+df_2016['평균 풍속(m/s)'][93]+df_2016['평균 풍속(m/s)'][94]+df_2016['평균 풍속(m/s)'][95]+df['wind_avg'][0])/5
df['humidity_5'][1] = (df_2016['평균 상대습도(%)'][92]+df_2016['평균 상대습도(%)'][93]+df_2016['평균 상대습도(%)'][94]+df_2016['평균 상대습도(%)'][95]+df['humidity_avg'][0])/5
# Out:
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/1496541763.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['temp_5'][1]= (df_2016['평균기온(°C)'][92]+df_2016['평균기온(°C)'][93]+df_2016['평균기온(°C)'][94]+df_2016['평균기온(°C)'][95]+df['temp_avg'][0])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/1496541763.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rain_5'][1] = (df_2016['일강수량(mm)'][92]+df_2016['일강수량(mm)'][93]+df_2016['일강수량(mm)'][94]+df_2016['일강수량(mm)'][95]+df['rain_avg'][0])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/1496541763.py:3: SettingWithCopyWarning:
# ...

# %%
df['temp_5'][2]= (df_2016['평균기온(°C)'][93]+df_2016['평균기온(°C)'][94]+df_2016['평균기온(°C)'][95]+df['temp_avg'][0]+df['temp_avg'][1])/5
df['rain_5'][2] = (df_2016['일강수량(mm)'][93]+df_2016['일강수량(mm)'][94]+df_2016['일강수량(mm)'][95]+df['rain_avg'][0]+df['rain_avg'][1])/5
df['wind_5'][2] = (df_2016['평균 풍속(m/s)'][93]+df_2016['평균 풍속(m/s)'][94]+df_2016['평균 풍속(m/s)'][95]+df['wind_avg'][0]+df['wind_avg'][1])/5
df['humidity_5'][2] = (df_2016['평균 상대습도(%)'][93]+df_2016['평균 상대습도(%)'][94]+df_2016['평균 상대습도(%)'][95]+df['humidity_avg'][0]+df['humidity_avg'][1])/5
# Out:
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/3311060120.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['temp_5'][2]= (df_2016['평균기온(°C)'][93]+df_2016['평균기온(°C)'][94]+df_2016['평균기온(°C)'][95]+df['temp_avg'][0]+df['temp_avg'][1])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/3311060120.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rain_5'][2] = (df_2016['일강수량(mm)'][93]+df_2016['일강수량(mm)'][94]+df_2016['일강수량(mm)'][95]+df['rain_avg'][0]+df['rain_avg'][1])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/3311060120.py:3: SettingWithCopyWarning:
# ...

# %%
df['temp_5'][3]= (df_2016['평균기온(°C)'][94]+df_2016['평균기온(°C)'][95]+df['temp_avg'][0]+df['temp_avg'][1]+df['temp_avg'][2])/5
df['rain_5'][3] = (df_2016['일강수량(mm)'][94]+df_2016['일강수량(mm)'][95]+df['rain_avg'][0]+df['rain_avg'][1]+df['rain_avg'][2])/5
df['wind_5'][3] = (df_2016['평균 풍속(m/s)'][94]+df_2016['평균 풍속(m/s)'][95]+df['wind_avg'][0]+df['wind_avg'][1]+df['wind_avg'][2])/5
df['humidity_5'][3] = (df_2016['평균 상대습도(%)'][94]+df_2016['평균 상대습도(%)'][95]+df['humidity_avg'][0]+df['humidity_avg'][1]+df['humidity_avg'][2])/5
# Out:
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/1123193134.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['temp_5'][3]= (df_2016['평균기온(°C)'][94]+df_2016['평균기온(°C)'][95]+df['temp_avg'][0]+df['temp_avg'][1]+df['temp_avg'][2])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/1123193134.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rain_5'][3] = (df_2016['일강수량(mm)'][94]+df_2016['일강수량(mm)'][95]+df['rain_avg'][0]+df['rain_avg'][1]+df['rain_avg'][2])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/1123193134.py:3: SettingWithCopyWarning:
# ...

# %%
df['temp_5'][4]= (df_2016['평균기온(°C)'][95]+df['temp_avg'][0]+df['temp_avg'][1]+df['temp_avg'][2]+df['temp_avg'][3])/5
df['rain_5'][4] = (df_2016['일강수량(mm)'][95]+df['rain_avg'][0]+df['rain_avg'][1]+df['rain_avg'][2]+df['rain_avg'][3])/5
df['wind_5'][4] = (df_2016['평균 풍속(m/s)'][95]+df['wind_avg'][0]+df['wind_avg'][1]+df['wind_avg'][2]+df['wind_avg'][3])/5
df['humidity_5'][4] = (df_2016['평균 상대습도(%)'][95]+df['humidity_avg'][0]+df['humidity_avg'][1]+df['humidity_avg'][2]+df['humidity_avg'][3])/5
# Out:
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/4075721302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['temp_5'][4]= (df_2016['평균기온(°C)'][95]+df['temp_avg'][0]+df['temp_avg'][1]+df['temp_avg'][2]+df['temp_avg'][3])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/4075721302.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rain_5'][4] = (df_2016['일강수량(mm)'][95]+df['rain_avg'][0]+df['rain_avg'][1]+df['rain_avg'][2]+df['rain_avg'][3])/5
# C:\Users\HJ\AppData\Local\Temp/ipykernel_17596/4075721302.py:3: SettingWithCopyWarning:
# ...

# %%
df.head(6)
# Out:
#     do observatory         day  temp_avg  rain_avg  wind_avg  humidity_avg  \
# 0  경기도         동두천  2017-01-01       1.8       0.0       0.6          76.3
# 1  경기도         동두천  2017-01-02       4.5       0.0       1.3          76.9
# 2  경기도         동두천  2017-01-03       0.7       0.0       1.2          66.5
# 3  경기도         동두천  2017-01-04       2.5       0.0       1.0          62.1
# 4  경기도         동두천  2017-01-05       2.7       0.0       1.3          60.1
# 5  경기도         동두천  2017-01-06       4.2       0.0       1.0          61.6
#
#   temp_5 rain_5 wind_5 humidity_5
# 0   0.96    0.1   2.68       50.9
# 1   0.84    0.0    2.1      54.06
# 2   1.78    0.0   2.04      59.46
# 3   1.94    0.0   1.56       64.8
# 4    2.4    0.0   1.22      69.06
# 5   2.44    0.0   1.08      68.38

# %%
df.to_csv('2018_climate_final.csv')
