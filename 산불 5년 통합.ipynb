# %%
import pandas as pd

# %%
a = pd.read_excel('2017_fire_last.xlsx')
b = pd.read_excel('2018_fire_last.xlsx')
c = pd.read_excel('2019_fire_last.xlsx')
d = pd.read_excel('2020_fire_last.xlsx')
e = pd.read_excel('2021_fire_last.xlsx')

# %%
df = pd.concat([a,b,c,d,e])

# %%
df
# Out:
#      Unnamed: 0  damagearea               day             start  \
# 0             0        0.20  2017-01-10 15:40  2017-01-10 15:40
# 1             1        0.05  2017-01-11 14:22  2017-01-11 14:22
# 2             2        0.50  2017-01-11 20:25  2017-01-11 20:25
# 3             3        0.03  2017-01-12 16:19  2017-01-12 16:19
# 4             4        0.07  2017-01-14 21:44  2017-01-14 21:44
# ..          ...         ...               ...               ...
# 296         296        0.50  2021-12-29 14:20  2021-12-29 14:20
# 297         297        1.50   2021-12-29 2:42   2021-12-29 2:42
# 298         298        0.10   2021-12-29 5:47   2021-12-29 5:47
# 299         299        0.40  2021-12-30 11:16  2021-12-30 11:16
# 300         300        0.50  2021-12-30 14:57  2021-12-30 14:57
#
#                   end firecause    do sigungu eupmyeon dongri  ...  \
# 0    2017-01-10 18:30  기타(직접입력)   경기도      용인       이동      묵  ...
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#       index  Unnamed: 0  damagearea               day             start  \
# 0         0           0        0.20  2017-01-10 15:40  2017-01-10 15:40
# 1         1           1        0.05  2017-01-11 14:22  2017-01-11 14:22
# 2         2           2        0.50  2017-01-11 20:25  2017-01-11 20:25
# 3         3           3        0.03  2017-01-12 16:19  2017-01-12 16:19
# 4         4           4        0.07  2017-01-14 21:44  2017-01-14 21:44
# ...     ...         ...         ...               ...               ...
# 2316    296         296        0.50  2021-12-29 14:20  2021-12-29 14:20
# 2317    297         297        1.50   2021-12-29 2:42   2021-12-29 2:42
# 2318    298         298        0.10   2021-12-29 5:47   2021-12-29 5:47
# 2319    299         299        0.40  2021-12-30 11:16  2021-12-30 11:16
# 2320    300         300        0.50  2021-12-30 14:57  2021-12-30 14:57
#
#                    end firecause    do sigungu eupmyeon  ...             time  \
# ...

# %%
df.drop(['index','Unnamed: 0'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7280/642716625.py in <module>
# ----> 1 df.drop(['index','Unnamed: 0'], axis=1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df
# Out:
#       damagearea               day             start               end  \
# 0           0.20  2017-01-10 15:40  2017-01-10 15:40  2017-01-10 18:30
# 1           0.05  2017-01-11 14:22  2017-01-11 14:22  2017-01-11 16:00
# 2           0.50  2017-01-11 20:25  2017-01-11 20:25  2017-01-11 22:00
# 3           0.03  2017-01-12 16:19  2017-01-12 16:19  2017-01-12 17:30
# 4           0.07  2017-01-14 21:44  2017-01-14 21:44  2017-01-14 22:55
# ...          ...               ...               ...               ...
# 2316        0.50  2021-12-29 14:20  2021-12-29 14:20  2021-12-29 17:30
# 2317        1.50   2021-12-29 2:42   2021-12-29 2:42  2021-12-29 15:45
# 2318        0.10   2021-12-29 5:47   2021-12-29 5:47  2021-12-29 12:00
# 2319        0.40  2021-12-30 11:16  2021-12-30 11:16  2021-12-30 12:30
# 2320        0.50  2021-12-30 14:57  2021-12-30 14:57  2021-12-30 17:30
#
#      firecause    do sigungu eupmyeon dongri   bunji             time  temp  \
# ...

# %%
df['year'] = ''
df['month'] = ''

# %%
for i in range(len(df)):
    df['year'][i] = df['day'][i][:4]
    df['month'][i] = df['day'][i][5:7]
# Out:
# C:\Users\HJ\AppData\Local\Temp/ipykernel_7280/2559943053.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'][i] = df['day'][i][:4]
# C:\Users\HJ\AppData\Local\Temp/ipykernel_7280/2559943053.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month'][i] = df['day'][i][5:7]

# %%
df.columns
# Out:
# Index(['damagearea', 'day', 'start', 'end', 'firecause', 'do', 'sigungu',
#        'eupmyeon', 'dongri', 'bunji', 'time', 'temp', 'rain', 'wind',
#        'wind_direction', 'humidity', 'temp_5', 'rain_5', 'wind_5',
#        'humidity_5', 'year', 'month'],
#       dtype='object')

# %%
cols = ['damagearea', 'year', 'month', 'day', 'start', 'end', 'firecause', 'do', 'sigungu',
       'eupmyeon', 'dongri', 'bunji', 'time', 'temp', 'rain', 'wind',
       'wind_direction', 'humidity', 'temp_5', 'rain_5', 'wind_5',
       'humidity_5']

# %%
df= df[cols]

# %%
df.head(3)
# Out:
#    damagearea  year month               day             start  \
# 0        0.20  2017    01  2017-01-10 15:40  2017-01-10 15:40
# 1        0.05  2017    01  2017-01-11 14:22  2017-01-11 14:22
# 2        0.50  2017    01  2017-01-11 20:25  2017-01-11 20:25
#
#                 end firecause    do sigungu eupmyeon  ...             time  \
# 0  2017-01-10 18:30  기타(직접입력)   경기도      용인       이동  ...  0 days 02:50:00
# 1  2017-01-11 16:00  기타(직접입력)   강원도      춘천        서  ...  0 days 01:38:00
# 2  2017-01-11 22:00     쓰레기소각  경상북도      영양       청기  ...  0 days 01:35:00
#
#   temp rain  wind  wind_direction  humidity  temp_5  rain_5  wind_5  \
# 0  5.5  0.0   5.0             290        28    3.42    0.04    1.58
# 1  2.8  0.0   4.9             290        22    6.04    1.00    2.24
# 2 -0.1  0.0   2.7             290        50    2.10    0.00    3.38
#
#    humidity_5
# 0       62.94
# 1       64.80
# 2       64.52
#
# [3 rows x 22 columns]

# %%
a = pd.DataFrame(df.groupby('firecause')['year'].value_counts())

# %%
a.to_excel('화재원인별 연도총계.xlsx')

# %%
a[:50]
# Out:
#                 year
# firecause year
# 기타        2019   176
#           2020   144
#           2021   123
#           2018   108
#           2017     7
# 기타(직접입력)  2017   261
# 낙뢰        2017     2
# 논밭두렁소각    2018    57
#           2019    57
#           2020    41
#           2017    34
# 농산폐기물소각   2017    40
# 담뱃불실화     2020    47
#           2021    29
#           2017    21
#           2019    17
#           2018    11
# 등산객실화     2017    50
# 무속행위      2017     3
# 방화        2017     1
# 산나물채취객실화  2017     8
# 성묘객실화     2018    24
#           2017    20
#           2019    18
#           2020     9
# 쓰레기소각     2017    84
#           2019    78
#           2020    58
#           2018    52
#           2021    23
# 어린이불장난    2018     1
#           2019     1
# 입산자실화     2020   154
#           2018   132
#           2019   132
#           2021   109
#           2017     7
# 작업장실화     2017    11
# 주택화재비화    2020    50
#           2019    49
#           2018    37
# ...

# %%
a.index
# Out:
# MultiIndex([(      '기타', '2019'),
#             (      '기타', '2020'),
#             (      '기타', '2021'),
#             (      '기타', '2018'),
#             (      '기타', '2017'),
#             ('기타(직접입력)', '2017'),
#             (      '낙뢰', '2017'),
#             (  '논밭두렁소각', '2018'),
#             (  '논밭두렁소각', '2019'),
#             (  '논밭두렁소각', '2020'),
#             (  '논밭두렁소각', '2017'),
#             ( '농산폐기물소각', '2017'),
#             (   '담뱃불실화', '2020'),
#             (   '담뱃불실화', '2021'),
#             (   '담뱃불실화', '2017'),
#             (   '담뱃불실화', '2019'),
#             (   '담뱃불실화', '2018'),
#             (   '등산객실화', '2017'),
#             (    '무속행위', '2017'),
#             (      '방화', '2017'),
#             ('산나물채취객실화', '2017'),
#             (   '성묘객실화', '2018'),
#             (   '성묘객실화', '2017'),
#             (   '성묘객실화', '2019'),
#             (   '성묘객실화', '2020'),
#             (   '쓰레기소각', '2017'),
#             (   '쓰레기소각', '2019'),
# ...

# %%
a.columns
# Out:
# Index(['year'], dtype='object')

# %%
fig, ax = plt.subplots()
ax.pie(x=a.year)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7280/482517365.py in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.pie(x=a.year, labels='기타')
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize)
#    3057             explode = [0] * len(x)
#    3058         if len(x) != len(labels):
# ...

# %%
a = df.groupby('year').aggregate('mean')[['temp_5', 'rain_5', 'wind_5', 'humidity_5', 'damagearea',]]
a
# Out:
#          temp_5    rain_5    wind_5  humidity_5  damagearea
# year
# 2017  10.220600  0.659541  2.344444   53.130582    2.486085
# 2018  10.196209  0.932133  2.141137   56.938957    0.786114
# 2019   8.645227  0.480455  2.057992   54.329280    6.013958
# 2020   9.055746  0.479602  2.194235   55.814911    5.759662
# 2021   8.285449  0.874219  2.098206   56.772292    2.474618

# %%
a.corr()
# Out:
#               temp_5    rain_5    wind_5  humidity_5  damagearea
# temp_5      1.000000  0.250840  0.693801   -0.257931   -0.556366
# rain_5      0.250840  1.000000 -0.076186    0.596054   -0.933567
# wind_5      0.693801 -0.076186  1.000000   -0.561226   -0.247595
# humidity_5 -0.257931  0.596054 -0.561226    1.000000   -0.336731
# damagearea -0.556366 -0.933567 -0.247595   -0.336731    1.000000

# %%
sns.heatmap(a, annot=True)
# Out:
# <AxesSubplot:ylabel='year'>

# %%
a.to_excel('avg_year_damagearea.xlsx')

# %%
df['temp'].mean()
# Out:
# 14.537613097802653

# %%
df['day'].value_counts()
# Out:
# 2020-03-12 13:40    2
# 2017-04-27 14:25    2
# 2018-03-26 11:35    2
# 2019-04-06 11:30    2
# 2018-02-27 12:15    2
#                    ..
# 2018-04-02 10:40    1
# 2018-04-01 16:56    1
# 2018-04-01 14:15    1
# 2018-04-01 13:00    1
# 2021-12-30 14:57    1
# Name: day, Length: 2305, dtype: int64

# %%
df.drop('do_count', axis=1, inplace=True)

# %%
df = df.fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# damagearea        0
# day               0
# start             0
# end               0
# firecause         0
# do                0
# sigungu           0
# eupmyeon          0
# dongri            0
# bunji             0
# time              0
# temp              0
# rain              0
# wind              0
# wind_direction    0
# humidity          0
# temp_5            0
# rain_5            0
# wind_5            0
# humidity_5        0
# dtype: int64

# %%
a = pd.DataFrame(df.groupby('do')['year'].count())

# %%
a.to_excel('do_yaer.xlsx')

# %%
ab = pd.DataFrame(df.groupby('month')['day'].count())

# %%
ab.to_excel('month_count.xlsx')

# %%
import matplotlib.pyplot as plt

# %%
aa = pd.pivot_table(df,   index = ['do'],
                     columns = 'year',
                     values = ['temp','rain','wind','wind_direction'],
                     aggfunc = ['mean'], fill_value=0)

# %%
aa.corr()
# Out:
#                               mean                                          \
#                               rain
# year                          2017      2018      2019      2020      2021
#                     year
# mean rain           2017  1.000000 -0.098292 -0.098292  0.954012  0.225494
#                     2018 -0.098292  1.000000  1.000000 -0.076923 -0.076923
#                     2019 -0.098292  1.000000  1.000000 -0.076923 -0.076923
#                     2020  0.954012 -0.076923 -0.076923  1.000000 -0.076923
#                     2021  0.225494 -0.076923 -0.076923 -0.076923  1.000000
#      temp           2017  0.291279  0.193771  0.193771  0.219367  0.255859
#                     2018  0.198574  0.089804  0.089804  0.146307  0.184967
#                     2019  0.242182  0.125516  0.125516  0.172771  0.243998
#                     2020 -0.011562  0.076022  0.076022  0.049917 -0.200684
#                     2021  0.383513 -0.001240 -0.001240  0.297366  0.309138
# ...

# %%
import seaborn as sns

# %%
aa.to_excel('do_year_climate_mean.xlsx')

# %%
df.to_excel('fire_5.xlsx')

# %%
df
# Out:
#       damagearea  year month               day             start  \
# 0           0.20  2017    01  2017-01-10 15:40  2017-01-10 15:40
# 1           0.05  2017    01  2017-01-11 14:22  2017-01-11 14:22
# 2           0.50  2017    01  2017-01-11 20:25  2017-01-11 20:25
# 3           0.03  2017    01  2017-01-12 16:19  2017-01-12 16:19
# 4           0.07  2017    01  2017-01-14 21:44  2017-01-14 21:44
# ...          ...   ...   ...               ...               ...
# 2316        0.50  2021    12  2021-12-29 14:20  2021-12-29 14:20
# 2317        1.50  2021    12   2021-12-29 2:42   2021-12-29 2:42
# 2318        0.10  2021    12   2021-12-29 5:47   2021-12-29 5:47
# 2319        0.40  2021    12  2021-12-30 11:16  2021-12-30 11:16
# 2320        0.50  2021    12  2021-12-30 14:57  2021-12-30 14:57
#
#                    end firecause    do sigungu eupmyeon  ...             time  \
# 0     2017-01-10 18:30  기타(직접입력)   경기도      용인       이동  ...  0 days 02:50:00
# ...

# %%
df17 = pd.read_csv('C:/Users/HJ/Desktop/자료모음/1.origin(rawdata)/산불/2017_fire.CSV', encoding='cp949')
df18 = pd.read_csv('C:/Users/HJ/Desktop/자료모음/1.origin(rawdata)/산불/2018_fire.CSV')
df19 = pd.read_csv('C:/Users/HJ/Desktop/자료모음/1.origin(rawdata)/산불/2019_fire.CSV', encoding='cp949')
df20 = pd.read_csv('C:/Users/HJ/Desktop/자료모음/1.origin(rawdata)/산불/2020_fire.CSV', encoding='cp949')
df21 = pd.read_csv('C:/Users/HJ/Desktop/자료모음/1.origin(rawdata)/산불/2021_fire.CSV', encoding='cp949')

# %%
df17 = pd.DataFrame(df17['startdayofweek'])
df18 = pd.DataFrame(df18['startdayofweek'])
df19 = pd.DataFrame(df19['startdayofweek'])
df20 = pd.DataFrame(df20['startdayofweek'])
df21 = pd.DataFrame(df21['startdayofweek'])

# %%
aaa = pd.concat([df17,df18,df19,df20,df21], ignore_index=True)

# %%
aaa = aaa[:2321]

# %%
df16
# Out:
#     startdayofweek
# 0              목요일
# 1              금요일
# 2              토요일
# 3              토요일
# 4              일요일
# ..             ...
# 687            일요일
# 688            일요일
# 689            일요일
# 690            일요일
# 691            일요일
#
# [692 rows x 1 columns]

# %%
df17
# Out:
#     startdayofweek
# 0              목요일
# 1              월요일
# 2              화요일
# 3              목요일
# 4              목요일
# ..             ...
# 491            일요일
# 492            월요일
# 493            월요일
# 494            월요일
# 495            월요일
#
# [496 rows x 1 columns]

# %%
df18
# Out:
#     startdayofweek
# 0              목요일
# 1              월요일
# 2              화요일
# 3              목요일
# 4              목요일
# ..             ...
# 491            일요일
# 492            월요일
# 493            월요일
# 494            월요일
# 495            월요일
#
# [496 rows x 1 columns]

# %%
cb = pd.concat([df, aaa], axis=1, ignore_index=None)

# %%
cb.columns
# Out:
# Index(['damagearea', 'year', 'month', 'day', 'start', 'end', 'firecause', 'do',
#        'sigungu', 'eupmyeon', 'dongri', 'bunji', 'time', 'temp', 'rain',
#        'wind', 'wind_direction', 'humidity', 'temp_5', 'rain_5', 'wind_5',
#        'humidity_5', 'startdayofweek', '시간당 피해면적'],
#       dtype='object')

# %%
ax = pd.DataFrame(cb.groupby('startdayofweek')['year'].value_counts())
ax.values
# Out:
# array([[ 73],
#        [ 72],
#        [ 52],
#        [ 52],
#        [ 46],
#        [ 89],
#        [ 81],
#        [ 59],
#        [ 50],
#        [ 49],
#        [ 94],
#        [ 83],
#        [ 62],
#        [ 41],
#        [ 36],
#        [ 72],
#        [ 69],
#        [ 67],
#        [ 66],
#        [ 30],
#        [ 97],
#        [ 82],
#        [ 81],
#        [ 56],
#        [ 49],
#        [105],
#        [ 93],
#        [ 87],
#        [ 73],
#        [ 53],
#        [ 77],
#        [ 64],
#        [ 63],
#        [ 60],
#        [ 38]], dtype=int64)

# %%
dayofweek = pd.DataFrame(cb['startdayofweek'].value_counts())
dayofweek.to_excel('dayofweek.xlsx')

# %%
dayofweek.index
# Out:
# Index(['토요일', '일요일', '목요일', '수요일', '월요일', '화요일', '금요일'], dtype='object')

# %%
cb.pivot_table(index='day').to_excel('일별 피해규모 기상.xlsx')

# %%
cb['시간당 피해면적']=''

# %%
for i in range(len(cb)):
    cb['시간당 피해면적'][i] =

# %%
len(cb)
# Out:
# 2321

# %%
from datetime import datetime

# %%
cb['time'].to_da
# Out:
#       damagearea  year month               day             start  \
# 0           0.20  2017    01  2017-01-10 15:40  2017-01-10 15:40
# 1           0.05  2017    01  2017-01-11 14:22  2017-01-11 14:22
# 2           0.50  2017    01  2017-01-11 20:25  2017-01-11 20:25
# 3           0.03  2017    01  2017-01-12 16:19  2017-01-12 16:19
# 4           0.07  2017    01  2017-01-14 21:44  2017-01-14 21:44
# ...          ...   ...   ...               ...               ...
# 2316        0.50  2021    12  2021-12-29 14:20  2021-12-29 14:20
# 2317        1.50  2021    12   2021-12-29 2:42   2021-12-29 2:42
# 2318        0.10  2021    12   2021-12-29 5:47   2021-12-29 5:47
# 2319        0.40  2021    12  2021-12-30 11:16  2021-12-30 11:16
# 2320        0.50  2021    12  2021-12-30 14:57  2021-12-30 14:57
#
#                    end firecause    do sigungu eupmyeon  ... rain wind  \
# 0     2017-01-10 18:30  기타(직접입력)   경기도      용인       이동  ...  0.0  5.0
# ...

# %%
zz = pd.DataFrame(cb.groupby('time')[['temp', 'rain','wind','humidity', 'temp_5', 'rain_5','wind_5','humidity_5']])

# %%
zz = pd.pivot_table(cb[['temp', 'rain','wind','humidity', 'temp_5', 'rain_5','wind_5','humidity_5']], index=cb['time'])

# %%
zz
# Out:
#                  humidity  humidity_5  rain  rain_5   temp  temp_5  wind  \
# time
# #NAME?               42.5       54.08   0.0    0.13  14.65   11.85  3.70
# 0 days 00:00:00       0.0       56.12   0.0    2.44   0.00    6.22  0.00
# 0 days 00:09:00       0.0       73.18   0.0    0.00   0.00   13.78  0.00
# 0 days 00:14:00      45.0       65.80   0.0    1.12   8.20    5.86  5.50
# 0 days 00:15:00      45.0       57.85   0.0    0.36  11.00    4.95  4.45
# ...                   ...         ...   ...     ...    ...     ...   ...
# 2 days 04:46:00      23.0       30.72   0.0    0.00   0.00   -0.16  3.60
# 2 days 15:02:00      14.0       64.92   0.0    0.00  23.00   17.14  3.80
# 2 days 23:38:00      19.0       64.92   0.0    0.00  20.80   17.14  2.20
# 3 days 00:45:00      13.0       53.90   0.0    0.00   4.20    9.88  3.40
# 3 days 02:21:00      43.0       53.16   0.0    4.84  17.20    9.38  4.60
#
#                  wind_5
# time
# #NAME?             2.01
# 0 days 00:00:00    1.70
# ...

# %%
cb.isnull().sum()
# Out:
# damagearea        0
# year              0
# month             0
# day               0
# start             0
# end               0
# firecause         0
# do                0
# sigungu           0
# eupmyeon          0
# dongri            0
# bunji             0
# time              0
# temp              0
# rain              0
# wind              0
# wind_direction    0
# humidity          0
# temp_5            0
# rain_5            0
# wind_5            0
# humidity_5        0
# startdayofweek    0
# 시간당 피해면적          0
# dtype: int64

# %%
cb.to_excel('fire_last.xlsx')

# %%
cb.head()
# Out:
#    damagearea  year month               day             start  \
# 0        0.20  2017    01  2017-01-10 15:40  2017-01-10 15:40
# 1        0.05  2017    01  2017-01-11 14:22  2017-01-11 14:22
# 2        0.50  2017    01  2017-01-11 20:25  2017-01-11 20:25
# 3        0.03  2017    01  2017-01-12 16:19  2017-01-12 16:19
# 4        0.07  2017    01  2017-01-14 21:44  2017-01-14 21:44
#
#                 end firecause    do sigungu eupmyeon  ... wind wind_direction  \
# 0  2017-01-10 18:30  기타(직접입력)   경기도      용인       이동  ...  5.0            290
# 1  2017-01-11 16:00  기타(직접입력)   강원도      춘천        서  ...  4.9            290
# 2  2017-01-11 22:00     쓰레기소각  경상북도      영양       청기  ...  2.7            290
# 3  2017-01-12 17:30     등산객실화   강원도      강릉       사천  ...  4.4            320
# 4  2017-01-14 22:55  기타(직접입력)   강원도      양양       현북  ...  2.7            320
#
#   humidity  temp_5  rain_5  wind_5  humidity_5  startdayofweek  시간당 피해면적  계절
# ...

# %%
z = cb.groupby(cb['month'].value_counts())
z

# %%
pd.DataFrame(cb['wind'].mean)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7280/3353733400.py in <module>
# ----> 1 pd.DataFrame(cb['wind'].mean)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
aaa.columns
# Out:
# Index(['Unnamed: 0', 'damagearea', 'year', 'month', 'day', 'start', 'end',
#        'firecause', 'do', 'sigungu', 'eupmyeon', 'dongri', 'bunji', 'time',
#        'temp', 'rain', 'wind', 'wind_direction', 'humidity', 'temp_5',
#        'rain_5', 'wind_5', 'humidity_5', 'startdayofweek', '시간당 피해면적', '계절'],
#       dtype='object')

# %%
bb = aaa[['month','temp', 'rain', 'wind', 'wind_direction', 'humidity', 'temp_5',
       'rain_5', 'wind_5', 'humidity_5']]
bb
# Out:
#       month  temp  rain  wind  wind_direction  humidity  temp_5  rain_5  \
# 0         1   5.5   0.0   5.0             290        28    3.42    0.04
# 1         1   2.8   0.0   4.9             290        22    6.04    1.00
# 2         1  -0.1   0.0   2.7             290        50    2.10    0.00
# 3         1   5.0   0.0   4.4             320        48    5.10    0.44
# 4         1  -6.1   0.0   2.7             320        28    2.88    0.00
# ...     ...   ...   ...   ...             ...       ...     ...     ...
# 2316     12   9.2   0.0   4.1             250        64   -1.14    0.00
# 2317     12   0.0   0.0   0.0               0         0   -0.68    6.58
# 2318     12   0.0   0.0   0.0               0         0    0.52    0.00
# 2319     12   1.4   0.0   5.0             290        38   -6.46    0.04
# 2320     12   3.1   0.0   8.0             290        92   -6.46    0.04
#
#       wind_5  humidity_5
# 0       1.58       62.94
# 1       2.24       64.80
# ...

# %%
sns.pairplot(bb)

# %%
sns.boxplot(data=cb, x=cb['year'],y=cb['wind'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='wind'>

# %%
sns.boxplot(data=cb, x=cb['year'],y=cb['temp'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='temp'>

# %%
sns.boxplot(data=cb, x=cb['year'],y=cb['rain'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='rain'>

# %%
sns.boxplot(data=cb, x=cb['year'],y=cb['humidity'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='humidity'>

# %%
sns.boxplot(data=cb, x=cb['year'],y=cb['humidity'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='humidity'>

# %%
cb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2321 entries, 0 to 2320
# Data columns (total 23 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   damagearea      2321 non-null   float64
#  1   year            2321 non-null   object
#  2   month           2321 non-null   object
#  3   startdayofweek  2321 non-null   object
#  4   day             2321 non-null   object
#  5   start           2321 non-null   object
#  6   end             2321 non-null   object
#  7   firecause       2321 non-null   object
#  8   do              2321 non-null   object
#  9   sigungu         2321 non-null   object
#  10  eupmyeon        2321 non-null   object
#  11  dongri          2321 non-null   object
#  12  bunji           2321 non-null   object
#  13  time            2321 non-null   object
#  14  temp            2321 non-null   float64
#  15  temp_5          2321 non-null   float64
#  16  rain            2321 non-null   float64
# ...

# %%
plt.figure(figsize=(16,6))
sns.violinplot(y=cb['wind'], x=cb['month'])
# Out:
# <AxesSubplot:xlabel='month', ylabel='wind'>

# %%
plt.figure(figsize=(16,6))
sns.violinplot(y=cb['rain'], x=cb['month'])
# Out:
# <AxesSubplot:xlabel='month', ylabel='rain'>

# %%
plt.figure(figsize=(16,6))
sns.violinplot(y=cb['humidity'], x=cb['month'])
# Out:
# <AxesSubplot:xlabel='month', ylabel='humidity'>

# %%
plt.figure(figsize=(16,6))
sns.violinplot(y=cb['temp'], x=cb['month'], split=True)
# Out:
# <AxesSubplot:xlabel='month', ylabel='temp'>

# %%
sns.stripplot(y=cb['temp'], x=cb['month'], dodge=True)
# Out:
# <AxesSubplot:xlabel='month', ylabel='temp'>

# %%
cb[cb['year']=='2018']['humidity'].max()
# Out:
# 90

# %%
sns.boxplot(data=cb, x=cb['year'],y=cb['rain'])
# Out:
# <AxesSubplot:xlabel='year', ylabel='rain'>

# %%
sns.violinplot(data=cb, x=cb['month'],y=cb['wind'])
plt.savefig('월.png')

# %%
cb.columns
# Out:
# Index(['damagearea', 'year', 'month', 'day', 'start', 'end', 'firecause', 'do',
#        'sigungu', 'eupmyeon', 'dongri', 'bunji', 'time', 'temp', 'rain',
#        'wind', 'wind_direction', 'humidity', 'temp_5', 'rain_5', 'wind_5',
#        'humidity_5', 'startdayofweek', '시간당 피해면적', '계절'],
#       dtype='object')

# %%
cols = ['damagearea', 'year', 'month', 'startdayofweek', 'day', 'start', 'end', 'firecause', 'do',
       'sigungu', 'eupmyeon', 'dongri', 'bunji', 'time', 'temp', 'temp_5', 'rain','rain_5',
       'wind', 'wind_5', 'wind_direction', 'humidity', 'humidity_5' ]

# %%
cb = cb[cols]

# %%
cb
# Out:
#       damagearea  year month startdayofweek               day  \
# 0           0.20  2017    01            목요일  2017-01-10 15:40
# 1           0.05  2017    01            금요일  2017-01-11 14:22
# 2           0.50  2017    01            토요일  2017-01-11 20:25
# 3           0.03  2017    01            토요일  2017-01-12 16:19
# 4           0.07  2017    01            일요일  2017-01-14 21:44
# ...          ...   ...   ...            ...               ...
# 2316        0.50  2021    12            화요일  2021-12-29 14:20
# 2317        1.50  2021    12            화요일   2021-12-29 2:42
# 2318        0.10  2021    12            화요일   2021-12-29 5:47
# 2319        0.40  2021    12            수요일  2021-12-30 11:16
# 2320        0.50  2021    12            수요일  2021-12-30 14:57
#
#                  start               end firecause    do sigungu  ...  \
# 0     2017-01-10 15:40  2017-01-10 18:30  기타(직접입력)   경기도      용인  ...
# 1     2017-01-11 14:22  2017-01-11 16:00  기타(직접입력)   강원도      춘천  ...
# ...

# %%
cb.to_excel('last.xlsx')

# %%
z = pd.DataFrame(cb.groupby(cb.startdayofweek)[['damagearea','wind','rain','temp','humidity', 'wind_5','rain_5','temp_5','humidity_5']].mean())
z.to_excel('요일별 피해규모와 기상평균.xlsx')

# %%
cb.time.unique
# Out:
# <bound method Series.unique of 0       0 days 02:50:00
# 1       0 days 01:38:00
# 2       0 days 01:35:00
# 3       0 days 01:11:00
# 4       0 days 01:11:00
#              ...
# 2316    0 days 03:10:00
# 2317    0 days 13:03:00
# 2318    0 days 06:13:00
# 2319    0 days 01:14:00
# 2320    0 days 02:33:00
# Name: time, Length: 2321, dtype: object>

# %%
z = pd.read_excel('C:/Users/HJ/Desktop/자료모음/3.output(datamart)/추출결합/최종파일.xlsx')

# %%
z.head(3)
# Out:
#    Unnamed: 0  damagearea  year  month startdayofweek               day  \
# 0        1841     1944.00  2020      4            일요일  2020-04-24 15:39
# 1         528        0.02  2017     12            화요일  2017-12-01 15:35
# 2         342      765.12  2017      5            월요일  2017-05-06 11:42
#
#               start               end firecause    do  ...             time  \
# 0  2020-04-24 15:39  2020-04-27 18:00     입산자실화  경상북도  ...  3 days 02:21:00
# 1  2017-12-01 15:35  2017-12-04 16:20  기타(직접입력)  경상남도  ...  3 days 00:45:00
# 2  2017-05-06 11:42  2017-05-09 11:20  기타(직접입력)   강원도  ...  2 days 23:38:00
#
#    temp temp_5 rain rain_5  wind  wind_5  wind_direction  humidity  humidity_5
# 0  17.2   9.38  0.0   4.84   4.6    2.36             250        43       53.16
# 1   4.2   9.88  0.0   0.00   3.4    1.52             320        13       53.90
# 2  20.8  17.14  0.0   0.00   2.2    1.76             270        19       64.92
#
# [3 rows x 24 columns]

# %%
z['계절']=''
len(z)
# Out:
# 2321

# %%
for i in range(len(z)):
    if z['month'][i] == 3:
        z['계절'][i] = '봄'
    elif z['month'][i] == 4:
        z['계절'][i] = '봄'
    elif z['month'][i] == 5:
        z['계절'][i] = '봄'
    elif z['month'][i] == 6:
        z['계절'][i] = '여름'
    elif z['month'][i] == 7:
        z['계절'][i] = '여름'
    elif z['month'][i] == 8:
        z['계절'][i] = '여름'
    elif z['month'][i] == 9:
        z['계절'][i] = '가을'
    elif z['month'][i] == 10:
        z['계절'][i] = '가을'
    elif z['month'][i] == 11:
        z['계절'][i] = '가을'
    elif z['month'][i] == 12:
        z['계절'][i] = '겨울'
    elif z['month'][i] == 1:
        z['계절'][i] = '겨울'  
    elif z['month'][i] == 2:
        z['계절'][i] = '겨울'
# Out:
# C:\Users\HJ\AppData\Local\Temp/ipykernel_7280/863422567.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   z['계절'][i] = '봄'
# C:\Users\HJ\AppData\Local\Temp/ipykernel_7280/863422567.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   z['계절'][i] = '겨울'
# C:\Users\HJ\AppData\Local\Temp/ipykernel_7280/863422567.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   z['계절'][i] = '봄'
# ...

# %%
a = pd.DataFrame(z['계절'].value_counts())
a.to_excel('산불 계절별 발생건수 합.xlsx')

# %%
plt.figure(figsize=(12,5))
plt.bar(a.index, a.계절)
# Out:
# <BarContainer object of 4 artists>
# C:\Users\HJ\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 48388 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HJ\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 44200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HJ\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HJ\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 50668 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\HJ\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 47492 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...
